# %%
#IMPORTING NECESSARY LIBRARIES
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#READING THE CSV DATA
read2018 = pd.read_csv('2018-QS-World-University-Rankings.csv', encoding='latin-1')
read2019 = pd.read_csv('2019-QS-World-University-Rankings.csv', encoding='latin-1')
read2020 = pd.read_csv('2020-QS-World-University-Rankings.csv', encoding='latin-1')

# %%
#CHECKING HOW MANY ROWS AND COLUMNS ARE IN THE 2018 DATA SET
read2018.shape
# Out:
# (985, 22)

# %%
#CHECKING HOW MANY ROWS AND COLUMNS ARE IN THE 2019 DATA SET
read2019.shape
# Out:
# (1026, 22)

# %%
#CHECKING HOW MANY ROWS AND COLUMNS ARE IN THE 2020 DATA SET
read2020.shape
# Out:
# (1025, 22)

# %%
#READING THE TOP 5 ROWS
read2018.head(5)
# Out:
#   2018 2017                              Institution Name        Country  \
# 0  NaN  NaN                                           NaN            NaN
# 1    1    1  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# 2    2    2                           STANFORD UNIVERSITY  United States
# 3    3    3                            HARVARD UNIVERSITY  United States
# 4    4    5  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)  United States
#
#   Classification Unnamed: 5          Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0           SIZE      FOCUS  RESEARCH INTENSITY        AGE     STATUS
# 1              M         CO                  VH          5          B
# 2              L         FC                  VH          5          B
# 3              L         FC                  VH          5          B
# 4              S         CO                  VH          5          B
#
#   Academic Reputation  ... Unnamed: 12 Faculty Student Unnamed: 14  \
# ...

# %%
#DROPPING COLUMNS THAT DO NOT AFFECT RANKING IN 2018, AND NAn ROWS

R2018 = read2018.drop(["Classification","Unnamed: 5","Unnamed: 6","Unnamed: 7","Unnamed: 8","Unnamed: 12","Unnamed: 14","Unnamed: 16","Unnamed: 18","Unnamed: 20","Unnamed: 10"], axis= 1) # droping the label variable (tip) from the data
RD2018 = R2018.dropna(axis = 0, how ='any')
RD2018.head(5)
# Out:
#   2018 2017                              Institution Name         Country  \
# 1    1    1  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)    United States
# 2    2    2                           STANFORD UNIVERSITY   United States
# 3    3    3                            HARVARD UNIVERSITY   United States
# 4    4    5  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)   United States
# 5    5    4                       UNIVERSITY OF CAMBRIDGE  United Kingdom
#
#   Academic Reputation Employer Reputation Faculty Student  \
# 1                 100                 100             100
# 2                 100                 100             100
# 3                 100                 100            98.3
# 4                99.5                85.4             100
# 5                 100                 100             100
#
#   Citations per Faculty International Faculty International Students  \
# 1                  99.9                   100                   96.1
# ...

# %%
#READING THE TOP 5 ROWS
read2019.head(5)
# Out:
#   2019 2018                              Institution Name        Country  \
# 0  NaN  NaN                                           NaN            NaN
# 1    1    1   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)  United States
# 2    2    2                           STANFORD UNIVERSITY  United States
# 3    3    3                            HARVARD UNIVERSITY  United States
# 4    4    4  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)  United States
#
#   Classification Unnamed: 5          Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0           SIZE      FOCUS  RESEARCH INTENSITY        AGE     STATUS
# 1              M         CO                  VH          5          B
# 2              L         FC                  VH          5          B
# 3              L         FC                  VH          5          B
# 4              S         CO                  VH          5          B
#
#   Academic Reputation  ... Unnamed: 12 Faculty Student Unnamed: 14  \
# ...

# %%
#DROPPING COLUMNS THAT DO NOT AFFECT RANKING IN 2019, AND NAn ROWS

R2019 = read2019.drop(["Classification","Unnamed: 5","Unnamed: 6","Unnamed: 7","Unnamed: 8","Unnamed: 12","Unnamed: 14","Unnamed: 16","Unnamed: 18","Unnamed: 20","Unnamed: 10"], axis= 1) # droping the label variable (tip) from the data
RD2019 = R2019.dropna(axis = 0, how ='any')
RD2019.head(5)
# Out:
#   2019 2018                              Institution Name         Country  \
# 1    1    1   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# 2    2    2                           STANFORD UNIVERSITY   United States
# 3    3    3                            HARVARD UNIVERSITY   United States
# 4    4    4  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)   United States
# 5    5    6                          UNIVERSITY OF OXFORD  United Kingdom
#
#   Academic Reputation Employer Reputation Faculty Student  \
# 1                 100                 100             100
# 2                 100                 100             100
# 3                 100                 100            99.3
# 4                98.7                81.2             100
# 5                 100                 100             100
#
#   Citations per Faculty International Faculty International Students  \
# 1                  99.8                   100                   95.5
# ...

# %%
#DROPPING ROWS THAT DO NOT AFFECT RANKING IN 2020, AND NAn ROWS

R2020 = read2020.drop(["Classification","Unnamed: 5","Unnamed: 6","Unnamed: 7","Unnamed: 8","Unnamed: 12","Unnamed: 14","Unnamed: 16","Unnamed: 18","Unnamed: 20","Unnamed: 10"], axis= 1) 
RD2020 = R2020.dropna(axis = 0, how ='any')
RD2020.head(5)
# Out:
#   Rank in 2020 Rank in 2019                              Institution Name  \
# 1            1            1   Massachusetts Institute of Technology (MIT)
# 2            2            2                           Stanford University
# 3            3            3                            Harvard University
# 4            4            5                          University of Oxford
# 5            5            4  California Institute of Technology (Caltech)
#
#           Country Academic Reputation Employer Reputation Faculty Student  \
# 1   United States                 100                 100             100
# 2   United States                 100                 100             100
# 3   United States                 100                 100            98.7
# 4  United Kingdom                 100                 100             100
# 5   United States                97.8                81.2             100
#
#   Citations per Faculty International Faculty International Students  \
# ...

# %%
RD2020.shape
# Out:
# (913, 11)

# %%
RD2019.shape
# Out:
# (895, 11)

# %%
RD2018.shape
# Out:
# (906, 11)
